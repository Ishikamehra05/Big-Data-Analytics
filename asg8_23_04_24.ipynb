# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishikamehra05/Big-Data-Analytics/blob/main/asg8_23_04_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd

# Read CSV file using relative path
data = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Boston.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NX       506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS     NX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# ...

# %%
x=data.iloc[ :,0:1]
x
# Out:
#         CRIM
# 0    0.00632
# 1    0.02731
# 2    0.02729
# 3    0.03237
# 4    0.06905
# ..       ...
# 501  0.06263
# 502  0.04527
# 503  0.06076
# 504  0.10959
# 505  0.04741
#
# [506 rows x 1 columns]

# %%
main=data.head(20)
main
# Out:
#        CRIM    ZN  INDUS  CHAS     NX     RM    AGE     DIS  RAD    TAX  \
# 0   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311.0
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311.0
# ...

# %%
main.shape
# Out:
# (20, 14)

# %%
# !pip install missingno

# %%
import missingno as msn
msn.bar(main)
# Out:
# <Axes: >

# %%
x=main['INDUS']
x
# Out:
# 0     2.31
# 1     7.07
# 2     7.07
# 3     2.18
# 4     2.18
# 5     2.18
# 6     7.87
# 7     7.87
# 8     7.87
# 9     7.87
# 10    7.87
# 11    7.87
# 12    7.87
# 13    8.14
# 14    8.14
# 15    8.14
# 16    8.14
# 17    8.14
# 18    8.14
# 19    8.14
# Name: INDUS, dtype: float64

# %%
y=main.iloc[ :,0:3]
y
# Out:
#        CRIM    ZN  INDUS
# 0   0.00632  18.0   2.31
# 1   0.02731   0.0   7.07
# 2   0.02729   0.0   7.07
# 3   0.03237   0.0   2.18
# 4   0.06905   0.0   2.18
# 5   0.02985   0.0   2.18
# 6   0.08829  12.5   7.87
# 7   0.14455  12.5   7.87
# 8   0.21124  12.5   7.87
# 9   0.17004  12.5   7.87
# 10  0.22489  12.5   7.87
# 11  0.11747  12.5   7.87
# 12  0.09378  12.5   7.87
# 13  0.62976   0.0   8.14
# 14  0.63796   0.0   8.14
# 15  0.62739   0.0   8.14
# 16  1.05393   0.0   8.14
# 17  0.78420   0.0   8.14
# 18  0.80271   0.0   8.14
# 19  0.72580   0.0   8.14

# %%
# Assuming 'Hours Studied', 'Sleep Hours' are the independent variables (features)
# and 'Scores' is the dependent variable (target)

X = main[['AGE', 'RM']]  # Independent variables
y = main['INDUS']  # Dependent variable

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=78)

# %%
print(main.columns)
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %% [raw]
# model=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Predict on the testing data
y_pred = model.predict(X_test)

# Calculate R-squared score
r_squared = model.score(X_test, y_test)
print("R-squared:", r_squared)
# Out:
# R-squared: -36.93619135186217

# %%
import numpy as np
import pandas as pd

# Assuming 'main' is your DataFrame
# Randomly select 80% of indices
keep_indices = np.random.choice(main.index, int(len(main) * 0.8), replace=False)

# Create a DataFrame with 80% of the data
train_data = main.loc[keep_indices]

# Create a DataFrame with the remaining 20% of the data
test_data = main.drop(keep_indices)

# Separate features and target variable for training and testing data
X_train = train_data[['AGE', 'RM']]  # Independent variables for training
y_train = train_data['INDUS']  # Dependent variable for training

X_test = test_data[['AGE', 'RM']]  # Independent variables for testing
y_test = test_data['INDUS']  # Dependent variable for testing

# %%
y_pred
# Out:
# array([8.60442515, 7.22017499, 1.77849997, 7.41116414])

# %%
test_data
# Out:
#        CRIM    ZN  INDUS  CHAS     NX     RM    AGE     DIS  RAD    TAX  \
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 12  0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311.0
# 16  1.05393   0.0   8.14     0  0.538  5.935   29.3  4.4986    4  307.0
#
#     PTRATIO       B  LSTAT  MEDV
# 6      15.2  395.60  12.43  22.9
# 8      15.2  386.63  29.93  16.5
# 12     15.2  390.50  15.71  21.7
# 16     21.0  386.85   6.58  23.1

# %%
train_data
# Out:
#        CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 4   0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# 7   0.14455  12.5   7.87     0  0.524  6.172  96.1  5.9505    5  311.0
# 9   0.17004  12.5   7.87     0  0.524  6.004  85.9  6.5921    5  311.0
# 18  0.80271   0.0   8.14     0  0.538  5.456  36.6  3.7965    4  307.0
# 17  0.78420   0.0   8.14     0  0.538  5.990  81.7  4.2579    4  307.0
# 14  0.63796   0.0   8.14     0  0.538  6.096  84.5  4.4619    4  307.0
# 19  0.72580   0.0   8.14     0  0.538  5.727  69.5  3.7965    4  307.0
# 10  0.22489  12.5   7.87     0  0.524  6.377  94.3  6.3467    5  311.0
# 0   0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 5   0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222.0
# 13  0.62976   0.0   8.14     0  0.538  5.949  61.8  4.7075    4  307.0
# 11  0.11747  12.5   7.87     0  0.524  6.009  82.9  6.2267    5  311.0
# ...

# %%
# Convert y_pred and y_test to DataFrames for easier comparison and printing
df_results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# Print the first few rows to see the comparison
print(df_results.head())
# Out:
#     Actual  Predicted
# 6     7.87   8.604425
# 8     7.87   7.220175
# 12    7.87   1.778500
# 16    8.14   7.411164
